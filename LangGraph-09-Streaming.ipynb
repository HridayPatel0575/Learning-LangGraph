# %%
from langchain_ollama import ChatOllama
from langgraph.graph import StateGraph,START,END
from langchain_core.messages import BaseMessage
from langchain.messages import SystemMessage,HumanMessage
from langgraph.checkpoint.memory import MemorySaver
from pydantic import BaseModel,Field
from typing import TypedDict,Literal,Annotated
from langgraph.graph.message import add_messages

# %%
class Chatbot(TypedDict):
    message : Annotated[list[BaseMessage],add_messages]

# %%
llm = ChatOllama(
    model='qwen2:7b'
)

# %%
def chat(state:Chatbot):

    message=state['message']

    respond = llm.invoke(message)

    return {'messages': [response]}

# %%
graph = StateGraph(Chatbot)
checkpoint = MemorySaver()

graph.add_node('chat',chat)
graph.add_edge(START,'chat')
graph.add_edge('chat',END)

chat_bot=graph.compile(checkpointer=checkpoint)

# %%
for message_chunk,metadata in chat_bot.stream(
    {'message':[HumanMessage(content='how to make pizza at home')]},
    config={'configurable':{'thread_id':'thread-1'}},
    stream_mode='messages'
    ):
    if message_chunk.content:
        print(message_chunk.content,end=" ",flush=True)
# Out:
# Making  homemade  pizza  is  both  fun  and  delicious !  Here 's  a  simple  step -by -step  guide  on  how  to  make  classic ,  delicious  pizza :
#
#  ** Ingredients : **
#  -  ** For  the  Pizza  Dough :**
#     -   3  cups  of  all -purpose  flour  ( plus  extra  for  dust ing )
#     -   1  packet  of  yeast  ( about   2   1 / 4  teaspoons )
#     -   1  teaspoon  sugar
#     -   1  tablespoon  olive  oil
#     -   1  cup  warm  water
#     -  Salt  to  taste
#
#  -  ** For  the  Pizza  Sauce :**
#     -   1  can  of  crushed  tomatoes  or  tomato  sauce
#     -  Garlic  cloves ,  minced  ( optional )
#     -  Salt  and  pepper  to  taste
#
#  -  ** T opp ings : **
#     -  Cheese  ( M oz z arella  is  most  common ,  but  you  could  use  other  types  like  Parm esan ,  P ec or ino  Rom ano  for  a  stronger  flavor )
#     -  Other  toppings  like  sliced  meats  ( like  pepper oni  or  sal ami ),  onions ,  mushrooms ,  bell  peppers ,  ol ives ,  or  fresh  herbs .
#
#  ** Steps : **
#
#  1 .  ** Prepare  the  Dough : **
#      -  In  a  large  bowl ,  mix  together  flour  and  salt .
#      -  Diss olve  yeast  in  warm  water  with  sugar  and  let  sit  for  about   5  minutes  until  it  becomes  fro thy  ( this  activates  the  yeast ).
#      -  Mix  the  yeast  mixture  into  the  flour ,  gradually  adding  olive  oil  as  you  stir .  K ne ad  the  dough  until  smooth ,  this  can  be  done  by  hand  or  using  a  stand  mixer  fitted  with  a  dough  hook .
#      -  Let  the  dough  rise  in  an  o iled  bowl  covered  with  a  damp  cloth  for  about   1  hour  ( it  should  double  in  size ).
#
#  2 .  ** Prepare  the  Sauce : **
#      -  If  you  are  making  your  own  sauce  from  scratch ,  combine  the  canned  tomatoes ,  minced  garlic  ( if  using ),  salt ,  and  pepper  in  a  small  pot  and  simmer  until  it  thick ens .
#
#  3 .  ** Pre heat  Your  Oven : **
#      -  Pre heat  your  oven  to   4 5 0 °F  ( 2 3 0 °C ).  If  you  have  a  pizza  stone  or  peel ,  place  this  on  the  lowest  rack  of  your  oven  while  pre he ating .
#
#  4 .  ** Roll  Out  Dough : **
#      -  Light ly  dust  your  work  surface  with  flour  and  roll  out  the  dough  into  the  shape  of  your  pizza  pan  or  directly  onto  the  baking  sheet  if  you  don 't  use  a  pizza  stone .
#      -  Make  sure  it 's  thin  enough  so  that  the  pizza  cooks  evenly  but  thick  enough  to  hold  toppings .
#
#  5 .  ** Add  Sauce  and  T opp ings : **
#      -  Spread  the  sauce  over  the  dough ,  leaving  about   1 / 2  inch  around  the  edges  for  crust .
#      -  Add  your  chosen  toppings  in  an  even  layer  on  top  of  the  sauce .
#
#  6 .  ** B ake  Your  Pizza : **
#      -  Place  the  pizza  into  the  hot  oven  and  bake  for  about   8 - 1 5  minutes  or  until  the  crust  is  golden  brown  and  cheese  is  melted  and  bubb ly  ( check  at  the  lower  end  of  this  time  frame  as  you  don 't  want  it  to  burn ).
#
#  7 .  ** Let  It  Cool :**
#      -  Once  baked ,  remove  the  pizza  from  the  oven  and  let  it  cool  slightly  on  a  wire  rack  before  slicing .
#
#  Enjoy  your  freshly  made  pizza !  You  can  get  creative  with  different  toppings  or  sauces  depending  on  your  taste  preferences .
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 for message_chunk,metadata in chat_bot.stream(
#       2     {'message':[HumanMessage(content='how to make pizza at home')]},
#       3     config={'configurable':{'thread_id':'thread-1'}},
#       4     stream_mode='messages'
#       5     ):
#       6     if message_chunk.content:print(message_chunk.content,end=" ",flush=True)
#
# File c:\Users\Admin\Desktop\Codes\Learning-LangGraph\genvenv\Lib\site-packages\langgraph\pregel\main.py:2646, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2644 for task in loop.match_cached_writes():
#    2645     loop.output_writes(task.id, task.writes, cached=True)
# -> 2646 for _ in runner.tick(
#    2647     [t for t in loop.tasks.values() if not t.writes],
#    2648     timeout=self.step_timeout,
#    2649     get_waiter=get_waiter,
#    2650     schedule_task=loop.accept_push,
#    2651 ):
#    2652     # emit output
#    2653     yield from _output(
#    2654         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2655     )
#    2656 loop.after_tick()
#
# File c:\Users\Admin\Desktop\Codes\Learning-LangGraph\genvenv\Lib\site-packages\langgraph\pregel\_runner.py:258, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     256 # panic on failure or timeout
#     257 try:
# --> 258     _panic_or_proceed(
#     259         futures.done.union(f for f, t in futures.items() if t is not None),
#     260         panic=reraise,
#     261     )
#     262 except Exception as exc:
#     263     if tb := exc.__traceback__:
#
# File c:\Users\Admin\Desktop\Codes\Learning-LangGraph\genvenv\Lib\site-packages\langgraph\pregel\_runner.py:520, in _panic_or_proceed(futs, timeout_exc_cls, panic)
#     518                 interrupts.append(exc)
#     519             elif fut not in SKIP_RERAISE_SET:
# --> 520                 raise exc
#     521 # raise combined interrupts
#     522 if interrupts:
#
# File c:\Users\Admin\Desktop\Codes\Learning-LangGraph\genvenv\Lib\site-packages\langgraph\pregel\_executor.py:80, in BackgroundExecutor.done(self, task)
#      78 """Remove the task from the tasks dict when it's done."""
#      79 try:
# ---> 80     task.result()
#      81 except GraphBubbleUp:
#      82     # This exception is an interruption signal, not an error
#      83     # so we don't want to re-raise it on exit
#      84     self.tasks.pop(task)
#
# File ~\AppData\Local\Programs\Python\python313\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\python313\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Local\Programs\Python\python313\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File c:\Users\Admin\Desktop\Codes\Learning-LangGraph\genvenv\Lib\site-packages\langgraph\pregel\_retry.py:42, in run_with_retry(task, retry_policy, configurable)
#      40     task.writes.clear()
#      41     # run the task
# ---> 42     return task.proc.invoke(task.input, config)
#      43 except ParentCommand as exc:
#      44     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\Users\Admin\Desktop\Codes\Learning-LangGraph\genvenv\Lib\site-packages\langgraph\_internal\_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File c:\Users\Admin\Desktop\Codes\Learning-LangGraph\genvenv\Lib\site-packages\langgraph\_internal\_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# Cell In[7], line 7, in chat(state)
#       3 message=state['message']
#       5 respond = llm.invoke(message)
# ----> 7 return {'messages': [response]}
#
# NameError: name 'response' is not defined
# During task with name 'chat' and id '92ea3b6b-2655-0fec-e1eb-2345700cdff5'
